# %% [markdown]
# # Orogenic landscapes modelling
#
# In this example, we simulate landscape evolution in response to two simple climatic scenarios:
# + **uniform** and
# + **orographic** precipitation.
#
# <div align="center">
#     <img src="images/oro_rain.jpg" alt="orographic precipitation" width="450" height="200"/>
# </div>
#
# We investigate the drainage network dynamics and the steady-state fluvial patterns that emerge from an application of these climatic forcing mechanisms.
#
# The first part of the scenario starts from a flat topography subjected to a constant and uniform rate of tectonic rock uplift (>1 mm/a) and precipitation (1 m/a). The domain is rectangular and the four edges are kept at a constant base-level elevation. The area is a 40x80 km domain.
#
# After 8 Ma, the second scenario is applied and consists in a linearly varying rainfall pattern corresponding to an orographic precipitation with the same uniform tectonic uplift rate. The Northern part of the domain is experiencing a 2 m/a precipitation rate and the Southern part is subject to a 0.1 m/a precipitation rate for the next 12 Ma.
#
# ## Initial settings
#
# For this model, we use the *stream power law sediment transport model* which scale the incision rate $E$ as a power function of surface water discharge $A$ and slope $S=\nabla z$:
#
# $$ E = \kappa A^m (\nabla z)^n$$
#
# where $\kappa$ is the erodibility coefficient dependent on lithology and mean precipitation rate, channel width, flood frequency, channel hydraulics.
#
# The values given to these parameters ($\kappa$, $m$, $n$) need to be set in the **XmL** input file.
#
# For this particular setting we do not need to record any deposition as the model is purely erosive. To speed up the model we turn off the deposition computation in **Badlands** by setting the **dep** element to *0* in the input file.
#
# ## Starting pyBadlands
#
# First we initialise the model and set the path to the **XmL** input file.
#
# You can edit the **XmL** configuration file at [/edit/volume/test/mountain/mountain.xml](/edit/volume/test/mountain/mountain.xml).
#
# To view the complete **XmL** options you can follow this link to github page: [complete.xml](https://github.com/badlands-model/pyBadlands/blob/master/test/input_complete.xml).

# %%
from pyBadlands.model import Model as badlandsModel

# Initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('mountain.xml')

# %% [markdown]
# ## Running pyBadlands
#
# We can run the model for a given period. The end time in the **XmL** input file is set to _50M years_ but you might want to run the model for a coupled of iterations and check the output before running the model for the entire simulation time. This is done by putting the time in the **run_to_time** function.
#
# Here we go for the full time directly... it should take about 2 minutes on a single processor if you keep the initial setting unchanged.

# %%
model.run_to_time(20000000)
# Out:
#    - Writing outputs (0.10 seconds; tNow = 0.0)
#    - Writing outputs (0.10 seconds; tNow = 50000.0)
#    - Writing outputs (0.10 seconds; tNow = 100000.0)
#    - Writing outputs (0.10 seconds; tNow = 150000.0)
#    - Writing outputs (0.10 seconds; tNow = 200000.0)
#    - Writing outputs (0.11 seconds; tNow = 250000.0)
#    - Writing outputs (0.11 seconds; tNow = 300000.0)
#    - Writing outputs (0.11 seconds; tNow = 350000.0)
#    - Writing outputs (0.10 seconds; tNow = 400000.0)
#    - Writing outputs (0.10 seconds; tNow = 450000.0)
#    - Writing outputs (0.12 seconds; tNow = 500000.0)
#    - Writing outputs (0.11 seconds; tNow = 550000.0)
#    - Writing outputs (0.15 seconds; tNow = 600000.0)
#    - Writing outputs (0.12 seconds; tNow = 650000.0)
#    - Writing outputs (0.11 seconds; tNow = 700000.0)
#    - Writing outputs (0.11 seconds; tNow = 750000.0)
#    - Writing outputs (0.14 seconds; tNow = 800000.0)
#    - Writing outputs (0.11 seconds; tNow = 850000.0)
#    - Writing outputs (0.11 seconds; tNow = 900000.0)
#    - Writing outputs (0.11 seconds; tNow = 950000.0)
#    - Writing outputs (0.11 seconds; tNow = 1000000.0)
#    - Writing outputs (0.11 seconds; tNow = 1050000.0)
#    - Writing outputs (0.12 seconds; tNow = 1100000.0)
#    - Writing outputs (0.11 seconds; tNow = 1150000.0)
#    - Writing outputs (0.10 seconds; tNow = 1200000.0)
#    - Writing outputs (0.11 seconds; tNow = 1250000.0)
#    - Writing outputs (0.11 seconds; tNow = 1300000.0)
#    - Writing outputs (0.11 seconds; tNow = 1350000.0)
#    - Writing outputs (0.11 seconds; tNow = 1400000.0)
#    - Writing outputs (0.11 seconds; tNow = 1450000.0)
#    - Writing outputs (0.11 seconds; tNow = 1500000.0)
#    - Writing outputs (0.11 seconds; tNow = 1550000.0)
#    - Writing outputs (0.11 seconds; tNow = 1600000.0)
#    - Writing outputs (0.11 seconds; tNow = 1650000.0)
#    - Writing outputs (0.11 seconds; tNow = 1700000.0)
#    - Writing outputs (0.11 seconds; tNow = 1750000.0)
#    - Writing outputs (0.11 seconds; tNow = 1800000.0)
#    - Writing outputs (0.11 seconds; tNow = 1850000.0)
#    - Writing outputs (0.10 seconds; tNow = 1900000.0)
#    - Writing outputs (0.11 seconds; tNow = 1950000.0)
#    - Writing outputs (0.11 seconds; tNow = 2000000.0)
#    - Writing outputs (0.11 seconds; tNow = 2050000.0)
#    - Writing outputs (0.11 seconds; tNow = 2100000.0)
#    - Writing outputs (0.11 seconds; tNow = 2150000.0)
#    - Writing outputs (0.11 seconds; tNow = 2200000.0)
#    - Writing outputs (0.11 seconds; tNow = 2250000.0)
#    - Writing outputs (0.11 seconds; tNow = 2300000.0)
#    - Writing outputs (0.11 seconds; tNow = 2350000.0)
#    - Writing outputs (0.11 seconds; tNow = 2400000.0)
#    - Writing outputs (0.11 seconds; tNow = 2450000.0)
#    - Writing outputs (0.11 seconds; tNow = 2500000.0)
#    - Writing outputs (0.11 seconds; tNow = 2550000.0)
#    - Writing outputs (0.11 seconds; tNow = 2600000.0)
#    - Writing outputs (0.11 seconds; tNow = 2650000.0)
#    - Writing outputs (0.10 seconds; tNow = 2700000.0)
#    - Writing outputs (0.11 seconds; tNow = 2750000.0)
#    - Writing outputs (0.11 seconds; tNow = 2800000.0)
#    - Writing outputs (0.11 seconds; tNow = 2850000.0)
#    - Writing outputs (0.11 seconds; tNow = 2900000.0)
#    - Writing outputs (0.11 seconds; tNow = 2950000.0)
#    - Writing outputs (0.11 seconds; tNow = 3000000.0)
#    - Writing outputs (0.10 seconds; tNow = 3050000.0)
#    - Writing outputs (0.10 seconds; tNow = 3100000.0)
#    - Writing outputs (0.11 seconds; tNow = 3150000.0)
#    - Writing outputs (0.11 seconds; tNow = 3200000.0)
#    - Writing outputs (0.11 seconds; tNow = 3250000.0)
#    - Writing outputs (0.11 seconds; tNow = 3300000.0)
#    - Writing outputs (0.10 seconds; tNow = 3350000.0)
#    - Writing outputs (0.11 seconds; tNow = 3400000.0)
#    - Writing outputs (0.11 seconds; tNow = 3450000.0)
#    - Writing outputs (0.11 seconds; tNow = 3500000.0)
#    - Writing outputs (0.10 seconds; tNow = 3550000.0)
#    - Writing outputs (0.11 seconds; tNow = 3600000.0)
#    - Writing outputs (0.10 seconds; tNow = 3650000.0)
#    - Writing outputs (0.10 seconds; tNow = 3700000.0)
#    - Writing outputs (0.11 seconds; tNow = 3750000.0)
#    - Writing outputs (0.10 seconds; tNow = 3800000.0)
#    - Writing outputs (0.10 seconds; tNow = 3850000.0)
#    - Writing outputs (0.11 seconds; tNow = 3900000.0)
#    - Writing outputs (0.11 seconds; tNow = 3950000.0)
#    - Writing outputs (0.11 seconds; tNow = 4000000.0)
#    - Writing outputs (0.11 seconds; tNow = 4050000.0)
#    - Writing outputs (0.11 seconds; tNow = 4100000.0)
#    - Writing outputs (0.11 seconds; tNow = 4150000.0)
#    - Writing outputs (0.11 seconds; tNow = 4200000.0)
#    - Writing outputs (0.10 seconds; tNow = 4250000.0)
#    - Writing outputs (0.11 seconds; tNow = 4300000.0)
#    - Writing outputs (0.11 seconds; tNow = 4350000.0)
#    - Writing outputs (0.11 seconds; tNow = 4400000.0)
#    - Writing outputs (0.11 seconds; tNow = 4450000.0)
#    - Writing outputs (0.11 seconds; tNow = 4500000.0)
#    - Writing outputs (0.11 seconds; tNow = 4550000.0)
#    - Writing outputs (0.11 seconds; tNow = 4600000.0)
#    - Writing outputs (0.11 seconds; tNow = 4650000.0)
#    - Writing outputs (0.11 seconds; tNow = 4700000.0)
#    - Writing outputs (0.11 seconds; tNow = 4750000.0)
#    - Writing outputs (0.11 seconds; tNow = 4800000.0)
#    - Writing outputs (0.11 seconds; tNow = 4850000.0)
#    - Writing outputs (0.11 seconds; tNow = 4900000.0)
#    - Writing outputs (0.11 seconds; tNow = 4950000.0)
#    - Writing outputs (0.11 seconds; tNow = 5000000.0)
#    - Writing outputs (0.11 seconds; tNow = 5050000.0)
#    - Writing outputs (0.12 seconds; tNow = 5100000.0)
#    - Writing outputs (0.13 seconds; tNow = 5150000.0)
#    - Writing outputs (0.12 seconds; tNow = 5200000.0)
#    - Writing outputs (0.11 seconds; tNow = 5250000.0)
#    - Writing outputs (0.11 seconds; tNow = 5300000.0)
#    - Writing outputs (0.11 seconds; tNow = 5350000.0)
#    - Writing outputs (0.11 seconds; tNow = 5400000.0)
#    - Writing outputs (0.11 seconds; tNow = 5450000.0)
#    - Writing outputs (0.11 seconds; tNow = 5500000.0)
#    - Writing outputs (0.11 seconds; tNow = 5550000.0)
#    - Writing outputs (0.11 seconds; tNow = 5600000.0)
#    - Writing outputs (0.11 seconds; tNow = 5650000.0)
#    - Writing outputs (0.11 seconds; tNow = 5700000.0)
#    - Writing outputs (0.11 seconds; tNow = 5750000.0)
#    - Writing outputs (0.11 seconds; tNow = 5800000.0)
#    - Writing outputs (0.17 seconds; tNow = 5850000.0)
#    - Writing outputs (0.14 seconds; tNow = 5900000.0)
#    - Writing outputs (0.11 seconds; tNow = 5950000.0)
#    - Writing outputs (0.11 seconds; tNow = 6000000.0)
#    - Writing outputs (0.11 seconds; tNow = 6050000.0)
#    - Writing outputs (0.11 seconds; tNow = 6100000.0)
#    - Writing outputs (0.11 seconds; tNow = 6150000.0)
#    - Writing outputs (0.13 seconds; tNow = 6200000.0)
#    - Writing outputs (0.13 seconds; tNow = 6250000.0)
#    - Writing outputs (0.13 seconds; tNow = 6300000.0)
#    - Writing outputs (0.13 seconds; tNow = 6350000.0)
#    - Writing outputs (0.12 seconds; tNow = 6400000.0)
#    - Writing outputs (0.15 seconds; tNow = 6450000.0)
#    - Writing outputs (0.13 seconds; tNow = 6500000.0)
#    - Writing outputs (0.13 seconds; tNow = 6550000.0)
#    - Writing outputs (0.11 seconds; tNow = 6600000.0)
#    - Writing outputs (0.11 seconds; tNow = 6650000.0)
#    - Writing outputs (0.13 seconds; tNow = 6700000.0)
#    - Writing outputs (0.12 seconds; tNow = 6750000.0)
#    - Writing outputs (0.11 seconds; tNow = 6800000.0)
#    - Writing outputs (0.11 seconds; tNow = 6850000.0)
#    - Writing outputs (0.11 seconds; tNow = 6900000.0)
#    - Writing outputs (0.13 seconds; tNow = 6950000.0)
#    - Writing outputs (0.13 seconds; tNow = 7000000.0)
#    - Writing outputs (0.12 seconds; tNow = 7050000.0)
#    - Writing outputs (0.13 seconds; tNow = 7100000.0)
#    - Writing outputs (0.12 seconds; tNow = 7150000.0)
#    - Writing outputs (0.11 seconds; tNow = 7200000.0)
#    - Writing outputs (0.11 seconds; tNow = 7250000.0)
#    - Writing outputs (0.11 seconds; tNow = 7300000.0)
#    - Writing outputs (0.11 seconds; tNow = 7350000.0)
#    - Writing outputs (0.14 seconds; tNow = 7400000.0)
#    - Writing outputs (0.13 seconds; tNow = 7450000.0)
#    - Writing outputs (0.13 seconds; tNow = 7500000.0)
#    - Writing outputs (0.11 seconds; tNow = 7550000.0)
#    - Writing outputs (0.11 seconds; tNow = 7600000.0)
#    - Writing outputs (0.12 seconds; tNow = 7650000.0)
#    - Writing outputs (0.11 seconds; tNow = 7700000.0)
#    - Writing outputs (0.11 seconds; tNow = 7750000.0)
#    - Writing outputs (0.12 seconds; tNow = 7800000.0)
#    - Writing outputs (0.11 seconds; tNow = 7850000.0)
#    - Writing outputs (0.11 seconds; tNow = 7900000.0)
#    - Writing outputs (0.11 seconds; tNow = 7950000.0)
#    - Writing outputs (0.11 seconds; tNow = 8000000.0)
#    - Writing outputs (0.10 seconds; tNow = 8050000.0)
#    - Writing outputs (0.11 seconds; tNow = 8100000.0)
#    - Writing outputs (0.11 seconds; tNow = 8150000.0)
#    - Writing outputs (0.11 seconds; tNow = 8200000.0)
#    - Writing outputs (0.12 seconds; tNow = 8250000.0)
#    - Writing outputs (0.10 seconds; tNow = 8300000.0)
#    - Writing outputs (0.11 seconds; tNow = 8350000.0)
#    - Writing outputs (0.11 seconds; tNow = 8400000.0)
#    - Writing outputs (0.10 seconds; tNow = 8450000.0)
#    - Writing outputs (0.13 seconds; tNow = 8500000.0)
#    - Writing outputs (0.11 seconds; tNow = 8550000.0)
#    - Writing outputs (0.10 seconds; tNow = 8600000.0)
#    - Writing outputs (0.11 seconds; tNow = 8650000.0)
#    - Writing outputs (0.16 seconds; tNow = 8700000.0)
#    - Writing outputs (0.10 seconds; tNow = 8750000.0)
#    - Writing outputs (0.11 seconds; tNow = 8800000.0)
#    - Writing outputs (0.11 seconds; tNow = 8850000.0)
#    - Writing outputs (0.11 seconds; tNow = 8900000.0)
#    - Writing outputs (0.12 seconds; tNow = 8950000.0)
#    - Writing outputs (0.11 seconds; tNow = 9000000.0)
#    - Writing outputs (0.11 seconds; tNow = 9050000.0)
#    - Writing outputs (0.10 seconds; tNow = 9100000.0)
#    - Writing outputs (0.10 seconds; tNow = 9150000.0)
#    - Writing outputs (0.11 seconds; tNow = 9200000.0)
#    - Writing outputs (0.11 seconds; tNow = 9250000.0)
#    - Writing outputs (0.10 seconds; tNow = 9300000.0)
#    - Writing outputs (0.11 seconds; tNow = 9350000.0)
#    - Writing outputs (0.11 seconds; tNow = 9400000.0)
#    - Writing outputs (0.11 seconds; tNow = 9450000.0)
#    - Writing outputs (0.11 seconds; tNow = 9500000.0)
#    - Writing outputs (0.11 seconds; tNow = 9550000.0)
#    - Writing outputs (0.11 seconds; tNow = 9600000.0)
#    - Writing outputs (0.11 seconds; tNow = 9650000.0)
#    - Writing outputs (0.11 seconds; tNow = 9700000.0)
#    - Writing outputs (0.10 seconds; tNow = 9750000.0)
#    - Writing outputs (0.11 seconds; tNow = 9800000.0)
#    - Writing outputs (0.11 seconds; tNow = 9850000.0)
#    - Writing outputs (0.11 seconds; tNow = 9900000.0)
#    - Writing outputs (0.11 seconds; tNow = 9950000.0)
#    - Writing outputs (0.11 seconds; tNow = 10000000.0)
#    - Writing outputs (0.10 seconds; tNow = 10050000.0)
#    - Writing outputs (0.10 seconds; tNow = 10100000.0)
#    - Writing outputs (0.11 seconds; tNow = 10150000.0)
#    - Writing outputs (0.11 seconds; tNow = 10200000.0)
#    - Writing outputs (0.10 seconds; tNow = 10250000.0)
#    - Writing outputs (0.10 seconds; tNow = 10300000.0)
#    - Writing outputs (0.10 seconds; tNow = 10350000.0)
#    - Writing outputs (0.11 seconds; tNow = 10400000.0)
#    - Writing outputs (0.11 seconds; tNow = 10450000.0)
#    - Writing outputs (0.10 seconds; tNow = 10500000.0)
#    - Writing outputs (0.10 seconds; tNow = 10550000.0)
#    - Writing outputs (0.10 seconds; tNow = 10600000.0)
#    - Writing outputs (0.10 seconds; tNow = 10650000.0)
#    - Writing outputs (0.10 seconds; tNow = 10700000.0)
#    - Writing outputs (0.11 seconds; tNow = 10750000.0)
#    - Writing outputs (0.11 seconds; tNow = 10800000.0)
#    - Writing outputs (0.10 seconds; tNow = 10850000.0)
#    - Writing outputs (0.10 seconds; tNow = 10900000.0)
#    - Writing outputs (0.11 seconds; tNow = 10950000.0)
#    - Writing outputs (0.10 seconds; tNow = 11000000.0)
#    - Writing outputs (0.10 seconds; tNow = 11050000.0)
#    - Writing outputs (0.10 seconds; tNow = 11100000.0)
#    - Writing outputs (0.10 seconds; tNow = 11150000.0)
#    - Writing outputs (0.11 seconds; tNow = 11200000.0)
#    - Writing outputs (0.10 seconds; tNow = 11250000.0)
#    - Writing outputs (0.11 seconds; tNow = 11300000.0)
#    - Writing outputs (0.10 seconds; tNow = 11350000.0)
#    - Writing outputs (0.10 seconds; tNow = 11400000.0)
#    - Writing outputs (0.11 seconds; tNow = 11450000.0)
#    - Writing outputs (0.11 seconds; tNow = 11500000.0)
#    - Writing outputs (0.10 seconds; tNow = 11550000.0)
#    - Writing outputs (0.10 seconds; tNow = 11600000.0)
#    - Writing outputs (0.11 seconds; tNow = 11650000.0)
#    - Writing outputs (0.11 seconds; tNow = 11700000.0)
#    - Writing outputs (0.10 seconds; tNow = 11750000.0)
#    - Writing outputs (0.11 seconds; tNow = 11800000.0)
#    - Writing outputs (0.11 seconds; tNow = 11850000.0)
#    - Writing outputs (0.10 seconds; tNow = 11900000.0)
#    - Writing outputs (0.11 seconds; tNow = 11950000.0)
#    - Writing outputs (0.10 seconds; tNow = 12000000.0)
#    - Writing outputs (0.11 seconds; tNow = 12050000.0)
#    - Writing outputs (0.11 seconds; tNow = 12100000.0)
#    - Writing outputs (0.10 seconds; tNow = 12150000.0)
#    - Writing outputs (0.11 seconds; tNow = 12200000.0)
#    - Writing outputs (0.13 seconds; tNow = 12250000.0)
#    - Writing outputs (0.11 seconds; tNow = 12300000.0)
#    - Writing outputs (0.11 seconds; tNow = 12350000.0)
#    - Writing outputs (0.11 seconds; tNow = 12400000.0)
#    - Writing outputs (0.11 seconds; tNow = 12450000.0)
#    - Writing outputs (0.11 seconds; tNow = 12500000.0)
#    - Writing outputs (0.11 seconds; tNow = 12550000.0)
#    - Writing outputs (0.12 seconds; tNow = 12600000.0)
#    - Writing outputs (0.11 seconds; tNow = 12650000.0)
#    - Writing outputs (0.11 seconds; tNow = 12700000.0)
#    - Writing outputs (0.11 seconds; tNow = 12750000.0)
#    - Writing outputs (0.11 seconds; tNow = 12800000.0)
#    - Writing outputs (0.11 seconds; tNow = 12850000.0)
#    - Writing outputs (0.11 seconds; tNow = 12900000.0)
#    - Writing outputs (0.11 seconds; tNow = 12950000.0)
#    - Writing outputs (0.11 seconds; tNow = 13000000.0)
#    - Writing outputs (0.11 seconds; tNow = 13050000.0)
#    - Writing outputs (0.11 seconds; tNow = 13100000.0)
#    - Writing outputs (0.11 seconds; tNow = 13150000.0)
#    - Writing outputs (0.11 seconds; tNow = 13200000.0)
#    - Writing outputs (0.11 seconds; tNow = 13250000.0)
#    - Writing outputs (0.11 seconds; tNow = 13300000.0)
#    - Writing outputs (0.13 seconds; tNow = 13350000.0)
#    - Writing outputs (0.11 seconds; tNow = 13400000.0)
#    - Writing outputs (0.11 seconds; tNow = 13450000.0)
#    - Writing outputs (0.12 seconds; tNow = 13500000.0)
#    - Writing outputs (0.11 seconds; tNow = 13550000.0)
#    - Writing outputs (0.11 seconds; tNow = 13600000.0)
#    - Writing outputs (0.11 seconds; tNow = 13650000.0)
#    - Writing outputs (0.10 seconds; tNow = 13700000.0)
#    - Writing outputs (0.11 seconds; tNow = 13750000.0)
#    - Writing outputs (0.11 seconds; tNow = 13800000.0)
#    - Writing outputs (0.11 seconds; tNow = 13850000.0)
#    - Writing outputs (0.11 seconds; tNow = 13900000.0)
#    - Writing outputs (0.11 seconds; tNow = 13950000.0)
#    - Writing outputs (0.11 seconds; tNow = 14000000.0)
#    - Writing outputs (0.11 seconds; tNow = 14050000.0)
#    - Writing outputs (0.14 seconds; tNow = 14100000.0)
#    - Writing outputs (0.12 seconds; tNow = 14150000.0)
#    - Writing outputs (0.11 seconds; tNow = 14200000.0)
#    - Writing outputs (0.11 seconds; tNow = 14250000.0)
#    - Writing outputs (0.12 seconds; tNow = 14300000.0)
#    - Writing outputs (0.10 seconds; tNow = 14350000.0)
#    - Writing outputs (0.12 seconds; tNow = 14400000.0)
#    - Writing outputs (0.11 seconds; tNow = 14450000.0)
#    - Writing outputs (0.10 seconds; tNow = 14500000.0)
#    - Writing outputs (0.12 seconds; tNow = 14550000.0)
#    - Writing outputs (0.11 seconds; tNow = 14600000.0)
#    - Writing outputs (0.11 seconds; tNow = 14650000.0)
#    - Writing outputs (0.11 seconds; tNow = 14700000.0)
#    - Writing outputs (0.16 seconds; tNow = 14750000.0)
#    - Writing outputs (0.11 seconds; tNow = 14800000.0)
#    - Writing outputs (0.11 seconds; tNow = 14850000.0)
#    - Writing outputs (0.12 seconds; tNow = 14900000.0)
#    - Writing outputs (0.15 seconds; tNow = 14950000.0)
#    - Writing outputs (0.15 seconds; tNow = 15000000.0)
#    - Writing outputs (0.19 seconds; tNow = 15050000.0)
#    - Writing outputs (0.16 seconds; tNow = 15100000.0)
#    - Writing outputs (0.25 seconds; tNow = 15150000.0)
#    - Writing outputs (0.13 seconds; tNow = 15200000.0)
#    - Writing outputs (0.11 seconds; tNow = 15250000.0)
#    - Writing outputs (0.11 seconds; tNow = 15300000.0)
#    - Writing outputs (0.10 seconds; tNow = 15350000.0)
#    - Writing outputs (0.11 seconds; tNow = 15400000.0)
#    - Writing outputs (0.11 seconds; tNow = 15450000.0)
#    - Writing outputs (0.12 seconds; tNow = 15500000.0)
#    - Writing outputs (0.11 seconds; tNow = 15550000.0)
#    - Writing outputs (0.11 seconds; tNow = 15600000.0)
#    - Writing outputs (0.11 seconds; tNow = 15650000.0)
#    - Writing outputs (0.10 seconds; tNow = 15700000.0)
#    - Writing outputs (0.11 seconds; tNow = 15750000.0)
#    - Writing outputs (0.11 seconds; tNow = 15800000.0)
#    - Writing outputs (0.11 seconds; tNow = 15850000.0)
#    - Writing outputs (0.11 seconds; tNow = 15900000.0)
#    - Writing outputs (0.11 seconds; tNow = 15950000.0)
#    - Writing outputs (0.14 seconds; tNow = 16000000.0)
#    - Writing outputs (0.12 seconds; tNow = 16050000.0)
#    - Writing outputs (0.11 seconds; tNow = 16100000.0)
#    - Writing outputs (0.11 seconds; tNow = 16150000.0)
#    - Writing outputs (0.11 seconds; tNow = 16200000.0)
#    - Writing outputs (0.11 seconds; tNow = 16250000.0)
#    - Writing outputs (0.11 seconds; tNow = 16300000.0)
#    - Writing outputs (0.11 seconds; tNow = 16350000.0)
#    - Writing outputs (0.11 seconds; tNow = 16400000.0)
#    - Writing outputs (0.11 seconds; tNow = 16450000.0)
#    - Writing outputs (0.11 seconds; tNow = 16500000.0)
#    - Writing outputs (0.11 seconds; tNow = 16550000.0)
#    - Writing outputs (0.11 seconds; tNow = 16600000.0)
#    - Writing outputs (0.13 seconds; tNow = 16650000.0)
#    - Writing outputs (0.11 seconds; tNow = 16700000.0)
#    - Writing outputs (0.13 seconds; tNow = 16750000.0)
#    - Writing outputs (0.11 seconds; tNow = 16800000.0)
#    - Writing outputs (0.11 seconds; tNow = 16850000.0)
#    - Writing outputs (0.11 seconds; tNow = 16900000.0)
#    - Writing outputs (0.10 seconds; tNow = 16950000.0)
#    - Writing outputs (0.21 seconds; tNow = 17000000.0)
#    - Writing outputs (0.13 seconds; tNow = 17050000.0)
#    - Writing outputs (0.11 seconds; tNow = 17100000.0)
#    - Writing outputs (0.11 seconds; tNow = 17150000.0)
#    - Writing outputs (0.11 seconds; tNow = 17200000.0)
#    - Writing outputs (0.12 seconds; tNow = 17250000.0)
#    - Writing outputs (0.11 seconds; tNow = 17300000.0)
#    - Writing outputs (0.11 seconds; tNow = 17350000.0)
#    - Writing outputs (0.11 seconds; tNow = 17400000.0)
#    - Writing outputs (0.11 seconds; tNow = 17450000.0)
#    - Writing outputs (0.12 seconds; tNow = 17500000.0)
#    - Writing outputs (0.11 seconds; tNow = 17550000.0)
#    - Writing outputs (0.11 seconds; tNow = 17600000.0)
#    - Writing outputs (0.11 seconds; tNow = 17650000.0)
#    - Writing outputs (0.11 seconds; tNow = 17700000.0)
#    - Writing outputs (0.11 seconds; tNow = 17750000.0)
#    - Writing outputs (0.11 seconds; tNow = 17800000.0)
#    - Writing outputs (0.11 seconds; tNow = 17850000.0)
#    - Writing outputs (0.11 seconds; tNow = 17900000.0)
#    - Writing outputs (0.11 seconds; tNow = 17950000.0)
#    - Writing outputs (0.12 seconds; tNow = 18000000.0)
#    - Writing outputs (0.10 seconds; tNow = 18050000.0)
#    - Writing outputs (0.12 seconds; tNow = 18100000.0)
#    - Writing outputs (0.12 seconds; tNow = 18150000.0)
#    - Writing outputs (0.13 seconds; tNow = 18200000.0)
#    - Writing outputs (0.11 seconds; tNow = 18250000.0)
#    - Writing outputs (0.11 seconds; tNow = 18300000.0)
#    - Writing outputs (0.13 seconds; tNow = 18350000.0)
#    - Writing outputs (0.12 seconds; tNow = 18400000.0)
#    - Writing outputs (0.12 seconds; tNow = 18450000.0)
#    - Writing outputs (0.11 seconds; tNow = 18500000.0)
#    - Writing outputs (0.13 seconds; tNow = 18550000.0)
#    - Writing outputs (0.12 seconds; tNow = 18600000.0)
#    - Writing outputs (0.12 seconds; tNow = 18650000.0)
#    - Writing outputs (0.13 seconds; tNow = 18700000.0)
#    - Writing outputs (0.11 seconds; tNow = 18750000.0)
#    - Writing outputs (0.12 seconds; tNow = 18800000.0)
#    - Writing outputs (0.12 seconds; tNow = 18850000.0)
#    - Writing outputs (0.12 seconds; tNow = 18900000.0)
#    - Writing outputs (0.13 seconds; tNow = 18950000.0)
#    - Writing outputs (0.12 seconds; tNow = 19000000.0)
#    - Writing outputs (0.12 seconds; tNow = 19050000.0)
#    - Writing outputs (0.11 seconds; tNow = 19100000.0)
#    - Writing outputs (0.11 seconds; tNow = 19150000.0)
#    - Writing outputs (0.11 seconds; tNow = 19200000.0)
#    - Writing outputs (0.12 seconds; tNow = 19250000.0)
#    - Writing outputs (0.12 seconds; tNow = 19300000.0)
#    - Writing outputs (0.11 seconds; tNow = 19350000.0)
#    - Writing outputs (0.12 seconds; tNow = 19400000.0)
#    - Writing outputs (0.11 seconds; tNow = 19450000.0)
#    - Writing outputs (0.12 seconds; tNow = 19500000.0)
#    - Writing outputs (0.14 seconds; tNow = 19550000.0)
#    - Writing outputs (0.12 seconds; tNow = 19600000.0)
#    - Writing outputs (0.11 seconds; tNow = 19650000.0)
#    - Writing outputs (0.12 seconds; tNow = 19700000.0)
#    - Writing outputs (0.11 seconds; tNow = 19750000.0)
#    - Writing outputs (0.12 seconds; tNow = 19800000.0)
#    - Writing outputs (0.13 seconds; tNow = 19850000.0)
#    - Writing outputs (0.11 seconds; tNow = 19900000.0)
#    - Writing outputs (0.20 seconds; tNow = 19950000.0)
# tNow = 20000000.0 (0.02 seconds)
#    - Writing outputs (0.12 seconds; tNow = 20000000.0)

# %% [markdown]
# ## Visualise output in Notebook
#
# For quick visualisation of the output at a given time step you can use 2 funtions:
# + visSurf
# + plotSurf
#
# The functions are based on [plot.ly](https://plot.ly) librairy and will give you a simple interactive view of the model outputs.

# %%
from pyBadlands import visSurf

view = visSurf.visSurf(folder=model.input.outDir, ncpus=1, dx=model.recGrid.resEdges, timestep=1)
view.plotSurf(width = 800, height = 600, zmin = -8000, zmax = 8000, color = 'Earth', reverse=False,
              dataV = 'z', subsample = 2)

view = visSurf.visSurf(folder=model.input.outDir, ncpus=1, dx=model.recGrid.resEdges, timestep=1)
view.plotSurf(width = 800, height = 600, zmin = -8000, zmax = 8000, color = 'Earth', reverse=False,
              dataV = 'z', subsample = 2)

# %% [markdown]
# # Visualise in Paraview
#
# For an in-depth visualisation of the model output it is recommended to install on your local machine a visualisation package such as [Paraview](http://www.paraview.org) or [Visit](https://wci.llnl.gov/simulation/computer-codes/visit/).
#
# **Badlands** outputs are created in the directory you've specified in your **XmL** input file. In cases where you have ran several instances of the same input you will end up with multiple directories with the same name followed with the simulation number.
#
# The folder contains xdmf series files:
# + **tin.series.xdmf** which will display the time series of surface evolution.
# + **flow.series.xdmf** which will display the time series of drainage network evolution.
#
# ## Elevation change
#
# | Time step 25| Time step 160 |
# | :-------------: |:-------------:|
# | <img src="images/step25.png" alt="Step 25" width="400" height="200" border="10" />| <img src="images/step160.png" alt="Step 160" width="400" height="200" border="10" /> |
#
# | Time step 250| Time step 400|
# | :-------------: |:-------------:|
# | <img src="images/step250.png" alt="Step 250" width="400" height="200" border="10" /> | <img src="images/step400.png" alt="Step 400" width="400" height="200" border="10" />|
#
# ## Drainage network
#
# | Time step 159| Time step 400 |
# | :-------------: |:-------------:|
# | <img src="images/step159.png" alt="Step 159" width="400" height="200" border="10" />| <img src="images/step400b.png" alt="Step 400" width="400" height="200" border="10" /> |
#
#
# Using paraview you will be able to extract several of the information computed by badlands and there also in the [Badlands companion](https://github.com/badlands-model/pyBadlands-Companion) container additional post-processing functions to look at:
# + **morphometrics **
# + **hydrometrics **
#
# In the next notebooks we will use the [Badlands companion](https://github.com/badlands-model/pyBadlands-Companion)  python classes to look at some of the available post-processing functions.
